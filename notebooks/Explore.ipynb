# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Distressed Housing Tracts
# `ffeic.gov-census-tract-1.2.1` Last Update: 2020-05-26T21:35:06
#
# _An xtract of a subset of columns from the FFEIC Census Flat File, including flags that indicate a tract is distressed._
#
#
# This dataset extracts the columns for distrssed tracts from the FFIEC compilation of census data, for use in their FFIEC Census Windows Application. It includes only 25 columns, the first 17 columns of the file, which have geographic identifiers, median income, and three population totals. The reamaining 8 columns hold flags to indicate if a tract is distressed.
#
# * 1205	Identifies Income Level Indicator
# * 1206	Meets current year's poverty CRA distressed criterion?
# * 1207	Meets current year's unemployment CRA distressed criterion?
# * 1208	Meets current year's population CRA distressed criterion?
# * 1209	Meets current year's remote rural (low density) CRA underserved criterion?
# * 1210	Meets at least one of the previous year's CRA distressed criteria?
# * 1211	Meets previous year's CRA underserved criterion?
# * 1212	Meets at least one of current or previous year's CRA distressed/underserved tract criteria?
#
#
# ## Caveats
#
# The 2017 file, as distributed by FFEIC, is broken: it includes a ZIP file with in the ZIP file, which Metapack cannot read. This file has been manually extracted and stored in the source package.
# ## Documentation Links
#
# * [File information](doc/cen2018.pdf) Description of the 2018 census file, including all columns. Other years are similar
# * [homepage](https://www.ffiec.gov/censusapp.htm)
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [ffeic_distressed](data/ffeic_distressed.csv)**. Distressed tracts
#
# ## References
# <ul><li> <strong><a href="https://www.ffiec.gov/Census/Census_Flat_Files/Census2013.zip#*.csv">ffeic_census_2013</a></strong>. 2013 Census Flat File</li><li> <strong><a href="https://www.ffiec.gov/Census/Census_Flat_Files/CENSUS2014.ZIP#*.csv">ffeic_census_2014</a></strong>. 2014 Census Flat File</li><li> <strong><a href="https://www.ffiec.gov/Census/Census_Flat_Files/CENSUS2015.zip#*.csv">ffeic_census_2015</a></strong>. 2015 Census Flat File</li><li> <strong><a href="https://www.ffiec.gov/Census/Census_Flat_Files/CENSUS2016.zip#*.csv">ffeic_census_2016</a></strong>. 2016 Census Flat File</li><li> <strong>ffeic_census_2017</string>, <em>data/Census2017.zip#*.csv</em>. 2017 Census Flat File</li><li> <strong><a href="https://www.ffiec.gov/Census/Census_Flat_Files/CENSUS2018.zip#*.csv">ffeic_census_2018</a></strong>. 2018 Census Flat File</li><ul>

# %%
df = pkg.resource('ffeic_distressed').dataframe()

# %%
df.head().T
# Out:
#                                            0                   1  \
# geoid                     14000US01001020100  14000US01001020200
# year                                    2013                2013
# msa_md_code                            33860               33860
# state                                      1                   1
# county                                     1                   1
# tract                                  20100               20200
# principal_city_flag                      NaN                 NaN
# small_county_flag                          T                   T
# split_tract_flag                           N                   N
# demo_flag                                  D                   D
# urban_rural_flag                           M                   U
# msa_family_income                      58143               58143
# msa_household_income                   46404               46404
# tract_family_income_pct               132.09                84.6
# ffeic_median_income                    61500               61500
# population                              1912                2170
# families                                 545                 456
# households                               696                 730
# income_level                               4                   3
# poverty_distressed
# unemployment_distressed
# population_distressed
# rural_underserved
# last_year_distressed
# last_year_underserved
# current_prior_distressed
#
#                                            2                   3  \
# geoid                     14000US01001020300  14000US01001020400
# year                                    2013                2013
# msa_md_code                            33860               33860
# state                                      1                   1
# county                                     1                   1
# tract                                  20300               20400
# principal_city_flag                      NaN                 NaN
# small_county_flag                          T                   T
# split_tract_flag                           N                   N
# demo_flag                                  D                   D
# urban_rural_flag                           U                   U
# msa_family_income                      58143               58143
# msa_household_income                   46404               46404
# tract_family_income_pct                91.74              115.73
# ffeic_median_income                    61500               61500
# population                              3373                4386
# families                                 913                1374
# households                              1287                1839
# income_level                               3                   3
# poverty_distressed
# unemployment_distressed
# population_distressed
# rural_underserved
# last_year_distressed
# last_year_underserved
# current_prior_distressed
#
#                                            4
# geoid                     14000US01001020500
# year                                    2013
# msa_md_code                            33860
# state                                      1
# county                                     1
# tract                                  20500
# principal_city_flag                      NaN
# small_county_flag                          T
# split_tract_flag                           N
# demo_flag                                  D
# urban_rural_flag                           M
# msa_family_income                      58143
# msa_household_income                   46404
# tract_family_income_pct               137.89
# ffeic_median_income                    61500
# population                             10766
# families                                2529
# households                              3741
# income_level                               4
# poverty_distressed
# unemployment_distressed
# population_distressed
# rural_underserved
# last_year_distressed
# last_year_underserved
# current_prior_distressed

# %%
df.population_distressed.value_counts()
# Out:
#      452840
# X      2316
# Name: population_distressed, dtype: int64

# %%
df.poverty_distressed.value_counts()
# Out:
#      441243
# X     13913
# Name: poverty_distressed, dtype: int64

# %%
df.current_prior_distressed.value_counts()
# Out:
#      430522
# X     24634
# Name: current_prior_distressed, dtype: int64
